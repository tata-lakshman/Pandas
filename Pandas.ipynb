# %% [markdown]
# <a href="https://colab.research.google.com/github/tata-lakshman/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                  #pandas
# Why pandas?
# Import datasets=>csv,excel,tsv,sql,etc.
# Data Cleaning=>missing values(blank values)&invalid values.
# size mutable=>we can easily add delete colums or rows.
# Reshape and pivoting of datasets.
# Efficien manipulation and extraction.
# Statistical analysis.
#       #2 Primary dataStructurs 1)Series(1D) 2)Data frame(2D)
# Data Structures are collection of datatypes that provide the best way of organizing items(values) in terms of memory usage.
# 1)Series=>A one-dimensional labeled homogeneous array,size immutable(we can't delete particular row from there we can only remove it.)
# 2)Data Frames=>A two-dimensional labeled,size-mutable tabular structure with potentially heterogenously typed columns.

# %%
import pandas as pd
s=pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s=pd.Series([10,20,30,40,'abc'])
print(s)
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4    abc
# dtype: object

# %% [markdown]
# #we can assign different index values as well

# %%
s2=pd.Series([10,20,30,40],index=['a','b','c','d'])
print(s2)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
print(s.dtype)
# Out:
# object

# %%
print(s.values)
# Out:
# [10 20 30 40 'abc']

# %%
print(s.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s2.index)
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
print(s.name)
# Out:
# None

# %%
s.name="mixed"
print(s)
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4    abc
# Name: mixed, dtype: object

# %%
print(s.name)
# Out:
# mixed

# %%
s=pd.Series([10,20,30,40,50])
s.name="Numbers"
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int64

# %%
#indexing
s[0]
# Out:
# np.int64(10)

# %%
print(s[0:2])
# Out:
# 0    10
# 1    20
# Name: Numbers, dtype: int64

# %% [markdown]
#              #iloc=>Location based indexing
# .iloc is used for integer-location based indexing in pandas DataFrames and Series. It allows you to select data based on its numerical position (from 0 to n-1) in the index, rather than its label. This is in contrast to .loc, which is used for label-based indexing.
#
# For example, s.iloc[3] retrieves the element at the 4th position (index 3) in the Series s, regardless of what the actual index labels are. If you had a DataFrame, you could use .iloc to select rows and columns by their integer position, like df.iloc[0, 1] to get the element in the first row and second column.

# %%
print(s.iloc[3])
# Out:
# 40

# %%
print(s.iloc[[1, 3, 4]])
# Out:
# 1    20
# 3    40
# 4    50
# Name: Numbers, dtype: int64

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int64

# %%
s.name="calories"
index=["apple","banana","cherry","orange","kiwi"]
s.index=index
print(s)
# Out:
# apple     10
# banana    20
# cherry    30
# orange    40
# kiwi      50
# Name: calories, dtype: int64

# %%
print(s.iloc["banana"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-199230563.py in <cell line: 0>()
# ----> 1 print(s.iloc["banana"])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1747             key = item_from_zerodim(key)
#    1748             if not is_integer(key):
# -> 1749                 raise TypeError("Cannot index by location index with a non-integer key")
#    1750
# ...

# %% [markdown]
# #TypeError: Cannot index by location index with a non-integer key means you are trying to use .iloc with a non-integer index label, 'banana'.
#
# Remember, .iloc is used for integer-location based indexing (using the numerical position, like 0, 1, 2, etc.), while .loc is used for label-based indexing (using the actual index labels, like 'apple', 'banana', etc.).
#
# To access the value for 'banana', you should use .loc:

# %% [markdown]
# #It performs operations on original index only
# s.iloc[2]=>But how can we know that 3rd index has banana.Here comes(loc)

# %%
s
# Out:
# apple     10
# banana    20
# cherry    30
# orange    40
# kiwi      50
# Name: calories, dtype: int64

# %% [markdown]
#             #loc=>label-based indexing.
# Think of your Series s with index labels 'apple', 'banana', 'cherry', etc. When you use s.loc['banana'], pandas looks for the index label 'banana' and returns the corresponding value.
#
# This is different from .iloc, which uses the integer position (0, 1, 2, ...) to select data. So, s.iloc[1] would give you the element at the second position (index 1), which happens to be 'banana' in your current Series, but it's selected by position, not label.
#
# .loc is particularly useful when your index has meaningful labels, as it makes your code more readable and less prone to errors if the order of your data changes.

# %%
#loc=>location based indexing
print(s.loc['banana'])
# Out:
# 20

# %% [markdown]
# #In label-based indexing(loc) your start as well as stop value both are included in the output.

# %%
s['banana':'orange']
# Out:
# banana    20
# cherry    30
# orange    40
# Name: calories, dtype: int64

# %% [markdown]
# #The main difference between .iloc and .loc in pandas lies in how they select data:
#
# .iloc (integer-location based indexing): This method uses the integer position of the rows and columns to select data. It's like accessing elements in a Python list or array using their numerical index (starting from 0). You use integers or slices of integers with .iloc.
# .loc (label-based indexing): This method uses the actual labels of the index and columns to select data. You use the labels (strings, numbers, or a mix) that are present in the index and column names with .loc.
#
# In short:
#
# Use .iloc when you want to select data based on its position.
#
# Use .loc when you want to select data based on its label.

# %%
#Dictionary
fruit_proten={
    "Avacado":2.0,
    "Guava":2.6,
    "Blackberry":2.0,
    "Orange":0.9,
    "Banana":1.1,
    "Apple":0.3,
    "Kiwi":1.1,
    "Promegranate":1.7,
    "Mango":0.8,
    "Cherry":1.0
}
s3=pd.Series(fruit_proten,name="Protein")
s3
# Out:
# Avacado         2.0
# Guava           2.6
# Blackberry      2.0
# Orange          0.9
# Banana          1.1
# Apple           0.3
# Kiwi            1.1
# Promegranate    1.7
# Mango           0.8
# Cherry          1.0
# Name: Protein, dtype: float64

# %%
#conditional Selection (true,false)
s3>1
# Out:
# Avacado          True
# Guava            True
# Blackberry       True
# Orange          False
# Banana           True
# Apple           False
# Kiwi             True
# Promegranate     True
# Mango           False
# Cherry          False
# Name: Protein, dtype: bool

# %% [markdown]
# s3 > 1: This part creates a boolean Series of the same size as s3. For each element in s3, it checks if the value is greater than 1. If it is, the corresponding value in the boolean Series is True; otherwise, it's False.
#
# s3[...]: When you use this boolean Series inside the square brackets [] after s3, pandas returns only the elements from s3 where the corresponding value in the boolean Series is True.
#
# So, s3[s3 > 1] effectively filters the s3 Series and shows you only the fruits that have a protein value greater than 1.

# %%
s3[s3>1]
# Out:
# Avacado         2.0
# Guava           2.6
# Blackberry      2.0
# Banana          1.1
# Kiwi            1.1
# Promegranate    1.7
# Name: Protein, dtype: float64

# %%
#Logical operators:and,or,not
[(s3>0.5) & (s3<1)]
# Out:
# [Avacado         False
#  Guava           False
#  Blackberry      False
#  Orange           True
#  Banana          False
#  Apple           False
#  Kiwi            False
#  Promegranate    False
#  Mango            True
#  Cherry          False
#  Name: Protein, dtype: bool]

# %%
s3[(s3>0.5) & (s3<1)]
# Out:
# Orange    0.9
# Mango     0.8
# Name: Protein, dtype: float64

# %%
s3[(s3>1) | (s3<=2)]
# Out:
# Avacado         2.0
# Guava           2.6
# Blackberry      2.0
# Orange          0.9
# Banana          1.1
# Apple           0.3
# Kiwi            1.1
# Promegranate    1.7
# Mango           0.8
# Cherry          1.0
# Name: Protein, dtype: float64

# %%
#not operation
s3[~(s3<1)]
# Out:
# Avacado         2.0
# Guava           2.6
# Blackberry      2.0
# Banana          1.1
# Kiwi            1.1
# Promegranate    1.7
# Cherry          1.0
# Name: Protein, dtype: float64

# %%
#modyfying the Series
s3["kiwi"]=2.8
s3
# Out:
# Avacado         2.0
# Guava           2.6
# Blackberry      2.0
# Orange          0.9
# Banana          1.1
# Apple           0.3
# Kiwi            1.1
# Promegranate    1.7
# Mango           0.8
# Cherry          1.0
# kiwi            2.8
# Name: Protein, dtype: object

# %%
print(s3.loc["Mango"])
# Out:
# 0.8

# %%
import numpy as np
ser=pd.Series(['a',np.nan,1,np.nan,23])

ser.notnull().sum()
# Out:
# np.int64(3)

# %%
print(ser.dtype)
# Out:
# object

# %%
#Data Frame:
data={
    "Name":["Alice","Bob","Charlie","David","Eve","Alice"],
    "Age":[25,30,22,np.nan,28,35],
    "Department":["HR","IT","Finance","HR","IT","HR"],
    "Salary":[50000,60000,55000,np.nan,62000,70000]
}
print(data)
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Alice'], 'Age': [25, 30, 22, nan, 28, 35], 'Department': ['HR', 'IT', 'Finance', 'HR', 'IT', 'HR'], 'Salary': [50000, 60000, 55000, nan, 62000, 70000]}

# %%
df=pd.DataFrame(data)
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David   NaN         HR      NaN
# 4      Eve  28.0         IT  62000.0
# 5    Alice  35.0         HR  70000.0

# %%
df.head()#By default it will give 5 values.
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David   NaN         HR      NaN
# 4      Eve  28.0         IT  62000.0

# %%
df.head(2)
# Out:
#     Name   Age Department   Salary
# 0  Alice  25.0         HR  50000.0
# 1    Bob  30.0         IT  60000.0

# %%
df.tail(3)#By default it will give bottem 5 rows.
# Out:
#     Name   Age Department   Salary
# 3  David   NaN         HR      NaN
# 4    Eve  28.0         IT  62000.0
# 5  Alice  35.0         HR  70000.0

# %%
#loc and iloc
df.iloc[3]
# Out:
# Name          David
# Age             NaN
# Department       HR
# Salary          NaN
# Name: 3, dtype: object

# %%
df.iloc[1:4]
# Out:
#       Name   Age Department   Salary
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David   NaN         HR      NaN

# %%
df.iloc[1:4,0:2]
# Out:
#       Name   Age
# 1      Bob  30.0
# 2  Charlie  22.0
# 3    David   NaN

# %%
df.loc[1:3,["Age","Department"]]
# Out:
#     Age Department
# 1  30.0         IT
# 2  22.0    Finance
# 3   NaN         HR

# %%
df["Age"]
# Out:
# 0    25.0
# 1    30.0
# 2    22.0
# 3     NaN
# 4    28.0
# 5    35.0
# Name: Age, dtype: float64

# %%
df.drop("Age",axis=1)
# Out:
#       Name Department   Salary
# 0    Alice         HR  50000.0
# 1      Bob         IT  60000.0
# 2  Charlie    Finance  55000.0
# 3    David         HR      NaN
# 4      Eve         IT  62000.0
# 5    Alice         HR  70000.0

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David   NaN         HR      NaN
# 4      Eve  28.0         IT  62000.0
# 5    Alice  35.0         HR  70000.0

# %%
df
# Out:
#   Department   Salary
# 0         HR  50000.0
# 1         IT  60000.0
# 2    Finance  55000.0
# 3         HR      NaN
# 4         IT  62000.0
# 5         HR  70000.0

# %%
df.shape
# Out:
# (6, 2)

# %%
import pandas as pd
df1=pd.DataFrame(data)
df1
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David   NaN         HR      NaN
# 4      Eve  28.0         IT  62000.0
# 5    Alice  35.0         HR  70000.0

# %%
df1.shape
# Out:
# (6, 4)

# %%
df1.info
# Out:
# <bound method DataFrame.info of       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David   NaN         HR      NaN
# 4      Eve  28.0         IT  62000.0
# 5    Alice  35.0         HR  70000.0>

# %%
df.describe()
# Out:
#              Salary
# count      5.000000
# mean   59400.000000
# std     7536.577473
# min    50000.000000
# 25%    55000.000000
# 50%    60000.000000
# 75%    62000.000000
# max    70000.000000

# %%
#Broad Casting
df["Salary"]=df["Salary"]+5000
df
# Out:
#   Department   Salary
# 0         HR  55000.0
# 1         IT  65000.0
# 2    Finance  60000.0
# 3         HR      NaN
# 4         IT  67000.0
# 5         HR  75000.0

# %%
#Renaming Column
df.rename(columns={"Department":"Dept"},inplace=True)
df
# Out:
#       Dept   Salary
# 0       HR  55000.0
# 1       IT  65000.0
# 2  Finance  60000.0
# 3       HR      NaN
# 4       IT  67000.0
# 5       HR  75000.0

# %%
df1.rename(columns={"Department":"Dept"},inplace=True)
df1
# Out:
#       Name   Age     Dept   Salary
# 0    Alice  25.0       HR  50000.0
# 1      Bob  30.0       IT  60000.0
# 2  Charlie  22.0  Finance  55000.0
# 3    David   NaN       HR      NaN
# 4      Eve  28.0       IT  62000.0
# 5    Alice  35.0       HR  70000.0

# %%
df["Salary"].unique()
# Out:
# array([55000., 65000., 60000.,    nan, 67000., 75000.])

# %%
df["Dept"].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)

# %%
df1["Name"].unique()
# Out:
# array(['Alice', 'Bob', 'Charlie', 'David', 'Eve'], dtype=object)

# %%
df["Dept"].value_counts()
# Out:
# Dept
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
df["Promotion Salary"]=df["Salary"]*10
df
# Out:
#       Dept   Salary  Promotion Salary
# 0       HR  55000.0          550000.0
# 1       IT  65000.0          650000.0
# 2  Finance  60000.0          600000.0
# 3       HR      NaN               NaN
# 4       IT  67000.0          670000.0
# 5       HR  75000.0          750000.0

# %%
#Data Cleaning
df.isnull().sum()
# Out:
# Dept                0
# Salary              1
# Promotion Salary    1
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Name      0
# Age       1
# Dept      0
# Salary    1
# dtype: int64

# %%
df.dropna()#With out passing any parameter so where the nullvalues are there the rows are removed and it doesn't effect the original dataset(we did'n use inplace=True)
# Out:
#       Dept   Salary  Promotion Salary
# 0       HR  55000.0          550000.0
# 1       IT  65000.0          650000.0
# 2  Finance  60000.0          600000.0
# 4       IT  67000.0          670000.0
# 5       HR  75000.0          750000.0

# %%
df
# Out:
#       Dept   Salary  Promotion Salary
# 0       HR  55000.0          550000.0
# 1       IT  65000.0          650000.0
# 2  Finance  60000.0          600000.0
# 3       HR      NaN               NaN
# 4       IT  67000.0          670000.0
# 5       HR  75000.0          750000.0

# %%
import pandas as pd
import numpy as np
data={
    "Name":["Alice","Bob","Charlie","David","Eve","Alice","Bob"],
    "Age":[25,30,22,np.nan,28,35,30],
    "Department":["HR","IT","Finance","HR","IT","HR","IT"],
    "Salary":[50000,60000,55000,np.nan,62000,70000,60000]
}
df=pd.DataFrame(data)
df.dropna(how='any')#any row that had only null value that will drop.
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 4      Eve  28.0         IT  62000.0
# 5    Alice  35.0         HR  70000.0
# 6      Bob  30.0         IT  60000.0

# %%
df.dropna(how='all')#all row that had only null value that will drop.
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David   NaN         HR      NaN
# 4      Eve  28.0         IT  62000.0
# 5    Alice  35.0         HR  70000.0

# %% [markdown]
# #Missing values
# getting rid=>dropna
#
# filling themup=>fillna

# %%
df.fillna(0)
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David   0.0         HR      0.0
# 4      Eve  28.0         IT  62000.0
# 5    Alice  35.0         HR  70000.0

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    25.0
# 1    30.0
# 2    22.0
# 3    28.0
# 4    28.0
# 5    35.0
# Name: Age, dtype: float64

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David  28.0         HR      NaN
# 4      Eve  28.0         IT  62000.0
# 5    Alice  35.0         HR  70000.0

# %%
df['Salary'].fillna(df['Salary'].median())
# Out:
# 0    50000.0
# 1    60000.0
# 2    55000.0
# 3    60000.0
# 4    62000.0
# 5    70000.0
# Name: Salary, dtype: float64

# %% [markdown]
# #fillna()
# forwardfill
#
# backwardfill

# %%
df['Salary'].fillna(method='ffill')
# Out:
# /tmp/ipython-input-2287196102.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Salary'].fillna(method='ffill')
# 0    50000.0
# 1    60000.0
# 2    55000.0
# 3    55000.0
# 4    62000.0
# 5    70000.0
# Name: Salary, dtype: float64

# %%
df['Salary'].fillna(method='bfill')
# Out:
# /tmp/ipython-input-2688032931.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Salary'].fillna(method='bfill')
# 0    50000.0
# 1    60000.0
# 2    55000.0
# 3    62000.0
# 4    62000.0
# 5    70000.0
# Name: Salary, dtype: float64

# %%
df['Name'].replace("Charlie","Ros")
# Out:
# 0    Alice
# 1      Bob
# 2      Ros
# 3    David
# 4      Eve
# 5    Alice
# Name: Name, dtype: object

# %% [markdown]
# #Duplicates

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David   NaN         HR      NaN
# 4      Eve  28.0         IT  62000.0
# 5    Alice  35.0         HR  70000.0
# 6      Bob  30.0         IT  60000.0

# %%
df_dup=df[df.duplicated()]
df_dup
# Out:
#   Name   Age Department   Salary
# 6  Bob  30.0         IT  60000.0

# %%
df=df.drop_duplicates()
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  22.0    Finance  55000.0
# 3    David   NaN         HR      NaN
# 4      Eve  28.0         IT  62000.0
# 5    Alice  35.0         HR  70000.0

# %%
#Invalid values
#Lambda=>python
df["Promotion Salary"]=df["Salary"]*10
df
# Out:
# /tmp/ipython-input-1148805034.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Promotion Salary"]=df["Salary"]*10
#       Name   Age Department   Salary  Promotion Salary
# 0    Alice  25.0         HR  50000.0          500000.0
# 1      Bob  30.0         IT  60000.0          600000.0
# 2  Charlie  22.0    Finance  55000.0          550000.0
# 3    David   NaN         HR      NaN               NaN
# 4      Eve  28.0         IT  62000.0          620000.0
# 5    Alice  35.0         HR  70000.0          700000.0

# %%
df['Promotion Salary']=df['Promotion Salary'].apply(lambda x:x/10 if x>60000 else x)
df
# Out:
# /tmp/ipython-input-1758132040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Promotion Salary']=df['Promotion Salary'].apply(lambda x:x/10 if x>60000 else x)
#       Name   Age Department   Salary  Promotion Salary
# 0    Alice  25.0         HR  50000.0           50000.0
# 1      Bob  30.0         IT  60000.0           60000.0
# 2  Charlie  22.0    Finance  55000.0           55000.0
# 3    David   NaN         HR      NaN               NaN
# 4      Eve  28.0         IT  62000.0           62000.0
# 5    Alice  35.0         HR  70000.0           70000.0

# %%
import pandas as pd
data={
    "Name":["Alice_Markes","Bob_Ram","Charlie_Mital","David_Rao","Eve_Eil","Alice_Jordan","Bob_Harsh"]

}
df2=pd.DataFrame(data)
df2
# Out:
#             Name
# 0   Alice_Markes
# 1        Bob_Ram
# 2  Charlie_Mital
# 3      David_Rao
# 4        Eve_Eil
# 5   Alice_Jordan
# 6      Bob_Harsh

# %%
df2[["First Name","Last Name"]]=df2["Name"].str.split("_",expand=True)
df2
# Out:
#             Name First Name Last Name
# 0   Alice_Markes      Alice    Markes
# 1        Bob_Ram        Bob       Ram
# 2  Charlie_Mital    Charlie     Mital
# 3      David_Rao      David       Rao
# 4        Eve_Eil        Eve       Eil
# 5   Alice_Jordan      Alice    Jordan
# 6      Bob_Harsh        Bob     Harsh

# %%
#Apply and lambda
def multiply_age(x):
  return x*2
df["Age"]=df["Age"].apply(multiply_age)
df
# Out:
# /tmp/ipython-input-874433439.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"]=df["Age"].apply(multiply_age)
#       Name   Age Department   Salary  Promotion Salary
# 0    Alice  50.0         HR  50000.0           50000.0
# 1      Bob  60.0         IT  60000.0           60000.0
# 2  Charlie  44.0    Finance  55000.0           55000.0
# 3    David   NaN         HR      NaN               NaN
# 4      Eve  56.0         IT  62000.0           62000.0
# 5    Alice  70.0         HR  70000.0           70000.0

# %%
df["Age"]=df["Age"].apply(lambda x:x/2)
df
# Out:
# /tmp/ipython-input-124226412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"]=df["Age"].apply(lambda x:x/2)
#       Name   Age Department   Salary  Promotion Salary
# 0    Alice  25.0         HR  50000.0           50000.0
# 1      Bob  30.0         IT  60000.0           60000.0
# 2  Charlie  22.0    Finance  55000.0           55000.0
# 3    David   NaN         HR      NaN               NaN
# 4      Eve  28.0         IT  62000.0           62000.0
# 5    Alice  35.0         HR  70000.0           70000.0

# %% [markdown]
# #Joins and merges
# joints=>left,right,outer&inner

# %%
department_info={
    "Department":["HR","IT","Finance"],
    "Location":["New York","san frinciso","chicago"],
    "manager":["Alice","Steve","Nino"]
}
df3=pd.DataFrame(department_info)
df3
# Out:
#   Department      Location manager
# 0         HR      New York   Alice
# 1         IT  san frinciso   Steve
# 2    Finance       chicago    Nino

# %%
pd.concat([df,df3])
# Out:
#       Name   Age Department   Salary  Promotion Salary      Location manager
# 0    Alice  25.0         HR  50000.0           50000.0           NaN     NaN
# 1      Bob  30.0         IT  60000.0           60000.0           NaN     NaN
# 2  Charlie  22.0    Finance  55000.0           55000.0           NaN     NaN
# 3    David   NaN         HR      NaN               NaN           NaN     NaN
# 4      Eve  28.0         IT  62000.0           62000.0           NaN     NaN
# 5    Alice  35.0         HR  70000.0           70000.0           NaN     NaN
# 0      NaN   NaN         HR      NaN               NaN      New York   Alice
# 1      NaN   NaN         IT      NaN               NaN  san frinciso   Steve
# 2      NaN   NaN    Finance      NaN               NaN       chicago    Nino

# %%
pd.concat([df,df3],axis=1)
# Out:
#       Name   Age Department   Salary  Promotion Salary Department  \
# 0    Alice  25.0         HR  50000.0           50000.0         HR
# 1      Bob  30.0         IT  60000.0           60000.0         IT
# 2  Charlie  22.0    Finance  55000.0           55000.0    Finance
# 3    David   NaN         HR      NaN               NaN        NaN
# 4      Eve  28.0         IT  62000.0           62000.0        NaN
# 5    Alice  35.0         HR  70000.0           70000.0        NaN
#
#        Location manager
# 0      New York   Alice
# 1  san frinciso   Steve
# 2       chicago    Nino
# 3           NaN     NaN
# 4           NaN     NaN
# 5           NaN     NaN

# %%
pd.concat([df,df3],axis=0)
# Out:
#       Name   Age Department   Salary  Promotion Salary      Location manager
# 0    Alice  25.0         HR  50000.0           50000.0           NaN     NaN
# 1      Bob  30.0         IT  60000.0           60000.0           NaN     NaN
# 2  Charlie  22.0    Finance  55000.0           55000.0           NaN     NaN
# 3    David   NaN         HR      NaN               NaN           NaN     NaN
# 4      Eve  28.0         IT  62000.0           62000.0           NaN     NaN
# 5    Alice  35.0         HR  70000.0           70000.0           NaN     NaN
# 0      NaN   NaN         HR      NaN               NaN      New York   Alice
# 1      NaN   NaN         IT      NaN               NaN  san frinciso   Steve
# 2      NaN   NaN    Finance      NaN               NaN       chicago    Nino

# %%
pd.merge(df,df3,on="Department")
# Out:
#       Name   Age Department   Salary  Promotion Salary      Location manager
# 0    Alice  25.0         HR  50000.0           50000.0      New York   Alice
# 1      Bob  30.0         IT  60000.0           60000.0  san frinciso   Steve
# 2  Charlie  22.0    Finance  55000.0           55000.0       chicago    Nino
# 3    David   NaN         HR      NaN               NaN      New York   Alice
# 4      Eve  28.0         IT  62000.0           62000.0  san frinciso   Steve
# 5    Alice  35.0         HR  70000.0           70000.0      New York   Alice

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-316b5ce4-a3fb-4510-8645-58ca3b61cefa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-316b5ce4-a3fb-4510-8645-58ca3b61cefa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("services_weekly.csv")
df.head()
# Out:
#    week  month           service  available_beds  patients_request  \
# 0     1      1         emergency              32                76
# 1     1      1           surgery              45               130
# 2     1      1  general_medicine              37               201
# 3     1      1               ICU              22                31
# 4     2      1         emergency              28               169
#
#    patients_admitted  patients_refused  patient_satisfaction  staff_morale  \
# 0                 32                44                    67            70
# 1                 45                85                    83            78
# 2                 37               164                    97            43
# 3                 22                 9                    84            91
# 4                 28               141                    75            64
#
#   event
# 0  none
# 1   flu
# 2   flu
# 3   flu
# 4  none

# %%
print(df.shape)
# Out:
# (208, 10)

# %%
print(df.columns)
# Out:
# Index(['week', 'month', 'service', 'available_beds', 'patients_request',
#        'patients_admitted', 'patients_refused', 'patient_satisfaction',
#        'staff_morale', 'event'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# week                     int64
# month                    int64
# service                 object
# available_beds           int64
# patients_request         int64
# patients_admitted        int64
# patients_refused         int64
# patient_satisfaction     int64
# staff_morale             int64
# event                   object
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   week                  208 non-null    int64
#  1   month                 208 non-null    int64
#  2   service               208 non-null    object
#  3   available_beds        208 non-null    int64
#  4   patients_request      208 non-null    int64
#  5   patients_admitted     208 non-null    int64
#  6   patients_refused      208 non-null    int64
#  7   patient_satisfaction  208 non-null    int64
#  8   staff_morale          208 non-null    int64
#  9   event                 208 non-null    object
# dtypes: int64(8), object(2)
# memory usage: 16.4+ KB
# None

# %%
print(df.describe())
# Out:
#              week       month  available_beds  patients_request  \
# count  208.000000  208.000000      208.000000        208.000000
# mean    26.500000    6.923077       30.346154         64.870192
# std     15.044539    3.634755       15.172929         58.738572
# min      1.000000    1.000000        8.000000          5.000000
# 25%     13.750000    4.000000       18.000000         23.750000
# 50%     26.500000    7.000000       27.500000         49.000000
# 75%     39.250000   10.000000       40.000000         86.000000
# max     52.000000   12.000000       74.000000        388.000000
#
#        patients_admitted  patients_refused  patient_satisfaction  staff_morale
# count         208.000000        208.000000            208.000000    208.000000
# mean           28.129808         36.740385             80.000000     72.567308
# std            14.676791         55.015763             11.125546     15.457759
# ...

# %%
print(df.isnull().sum())
# Out:
# week                    0
# month                   0
# service                 0
# available_beds          0
# patients_request        0
# patients_admitted       0
# patients_refused        0
# patient_satisfaction    0
# staff_morale            0
# event                   0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.corr(numeric_only=True))
# Out:
#                           week     month  available_beds  patients_request  \
# week                  1.000000  0.995103        0.136608         -0.098087
# month                 0.995103  1.000000        0.121017         -0.109450
# available_beds        0.136608  0.121017        1.000000          0.262282
# patients_request     -0.098087 -0.109450        0.262282          1.000000
# patients_admitted     0.106035  0.094005        0.949928          0.370548
# patients_refused     -0.133011 -0.141934        0.026614          0.968815
# patient_satisfaction  0.004878 -0.004062        0.018831         -0.049699
# staff_morale         -0.058352 -0.058633        0.093413          0.109494
#
#                       patients_admitted  patients_refused  \
# week                           0.106035         -0.133011
# month                          0.094005         -0.141934
# available_beds                 0.949928          0.026614
# ...

# %%
df.columns
# Out:
# Index(['week', 'month', 'service', 'available_beds', 'patients_request',
#        'patients_admitted', 'patients_refused', 'patient_satisfaction',
#        'staff_morale', 'event'],
#       dtype='object')

# %%
df["service"].value_counts()
# Out:
# service
# emergency           52
# surgery             52
# general_medicine    52
# ICU                 52
# Name: count, dtype: int64

# %%
df.dropna()
# Out:
#      week  month           service  available_beds  patients_request  \
# 0       1      1         emergency              32                76
# 1       1      1           surgery              45               130
# 2       1      1  general_medicine              37               201
# 3       1      1               ICU              22                31
# 4       2      1         emergency              28               169
# ..    ...    ...               ...             ...               ...
# 203    51     12               ICU              18                15
# 204    52     12         emergency              26               130
# 205    52     12           surgery              53                39
# 206    52     12  general_medicine              65               225
# 207    52     12               ICU              22                24
#
#      patients_admitted  patients_refused  patient_satisfaction  staff_morale  \
# ...

# %%
df.dropna(how="any")
# Out:
#      week  month           service  available_beds  patients_request  \
# 0       1      1         emergency              32                76
# 1       1      1           surgery              45               130
# 2       1      1  general_medicine              37               201
# 3       1      1               ICU              22                31
# 4       2      1         emergency              28               169
# ..    ...    ...               ...             ...               ...
# 203    51     12               ICU              18                15
# 204    52     12         emergency              26               130
# 205    52     12           surgery              53                39
# 206    52     12  general_medicine              65               225
# 207    52     12               ICU              22                24
#
#      patients_admitted  patients_refused  patient_satisfaction  staff_morale  \
# ...

# %%
df.dropna(how="all")
# Out:
#      week  month           service  available_beds  patients_request  \
# 0       1      1         emergency              32                76
# 1       1      1           surgery              45               130
# 2       1      1  general_medicine              37               201
# 3       1      1               ICU              22                31
# 4       2      1         emergency              28               169
# ..    ...    ...               ...             ...               ...
# 203    51     12               ICU              18                15
# 204    52     12         emergency              26               130
# 205    52     12           surgery              53                39
# 206    52     12  general_medicine              65               225
# 207    52     12               ICU              22                24
#
#      patients_admitted  patients_refused  patient_satisfaction  staff_morale  \
# ...

# %%
df["event"].value_counts()
# Out:
# event
# none        164
# flu          19
# donation     14
# strike       11
# Name: count, dtype: int64

# %%
#Duplicates
df_dup=df[df.duplicated()]
df_dup
# Out:
# Empty DataFrame
# Columns: [week, month, service, available_beds, patients_request, patients_admitted, patients_refused, patient_satisfaction, staff_morale, event]
# Index: []

# %%
df1=df.drop_duplicates
df1
# Out:
# <bound method DataFrame.drop_duplicates of      week  month           service  available_beds  patients_request  \
# 0       1      1         emergency              32                76
# 1       1      1           surgery              45               130
# 2       1      1  general_medicine              37               201
# 3       1      1               ICU              22                31
# 4       2      1         emergency              28               169
# ..    ...    ...               ...             ...               ...
# 203    51     12               ICU              18                15
# 204    52     12         emergency              26               130
# 205    52     12           surgery              53                39
# 206    52     12  general_medicine              65               225
# 207    52     12               ICU              22                24
#
#      patients_admitted  patients_refused  patient_satisfaction  staff_morale  \
# ...
